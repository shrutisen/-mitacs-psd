# %%
import pandas as pd
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

data1 = pd.read_csv('/content/BCICIV_2a_1.csv')
data2 = pd.read_csv('/content/BCICIV_2a_2.csv')
data3 = pd.read_csv('/content/BCICIV_2a_3.csv')
data4 = pd.read_csv('/content/BCICIV_2a_4.csv')
data5 = pd.read_csv('/content/BCICIV_2a_5.csv')
data6 = pd.read_csv('/content/BCICIV_2a_6.csv')
data7 = pd.read_csv('/content/BCICIV_2a_7.csv')
data8 = pd.read_csv('/content/BCICIV_2a_8.csv')
data9 = pd.read_csv('/content/BCICIV_2a_9.csv')

# %%
ctr=0
files = [data1,data2,data3,data4,data5,data6,data7,data8,data9]
final_alpha_beta_p300=[]
for data in files:
  # Extract the sensor values and time
  sensor_values0 = data['EEG-0'].values
  #print(sensor_values0)
  sensor_values1 = data['EEG-1'].values
  sensor_values2 = data['EEG-2'].values
  sensor_values3 = data['EEG-3'].values
  sensor_values4 = data['EEG-4'].values
  sensor_values5 = data['EEG-5'].values
  sensor_values6 = data['EEG-6'].values
  sensor_values7 = data['EEG-7'].values
  sensor_values8 = data['EEG-8'].values
  sensor_values9 = data['EEG-9'].values
  sensor_values10 = data['EEG-10'].values
  sensor_values11 = data['EEG-11'].values
  sensor_values12 = data['EEG-12'].values
  sensor_values13 = data['EEG-13'].values
  sensor_values14 = data['EEG-14'].values
  sensor_values15 = data['EEG-15'].values
  sensor_values16 = data['EEG-16'].values
  time = data['time'].values



  sensor_values_list = [sensor_values0, sensor_values1, sensor_values2,sensor_values3, sensor_values4, sensor_values5, sensor_values6, sensor_values7, sensor_values8, sensor_values9, sensor_values10, sensor_values11, sensor_values12, sensor_values13, sensor_values14, sensor_values15, sensor_values16]


  # Lists to store the feature values from all files
  alpha_powers = []
  beta_powers = []
  alpha_beta_powers = []
  delta_powers = []
  theta_powers = []
  gamma_powers = []

  # Function to calculate the PSD features
  def calculate_psd_features(sensor_values, fs):
      frequencies, psd = signal.welch(sensor_values, fs=fs)
      alpha_band = (8, 12)
      beta_band = (12, 30)
      delta_band = (0.5, 4)
      theta_band = (4, 8)
      gamma_band = (30, 45)

      alpha_power = np.trapz(psd[(frequencies >= alpha_band[0]) & (frequencies <= alpha_band[1])])
      beta_power = np.trapz(psd[(frequencies >= beta_band[0]) & (frequencies <= beta_band[1])])
      delta_power = np.trapz(psd[(frequencies >= delta_band[0]) & (frequencies <= delta_band[1])])
      theta_power = np.trapz(psd[(frequencies >= theta_band[0]) & (frequencies <= theta_band[1])])
      gamma_power = np.trapz(psd[(frequencies >= gamma_band[0]) & (frequencies <= gamma_band[1])])

      return alpha_power, beta_power, delta_power, theta_power, gamma_power

  for sensor_values in sensor_values_list:
      # Normalize the EEG data using Min-Max scaling
      scaler = MinMaxScaler(feature_range=(0, 45))
      normalized_sensor_values = scaler.fit_transform(sensor_values.reshape(-1, 1)).flatten()

      # Set the sampling frequency and time vector
      fs = 256  # Sample rate (adjust according to your data)
      t = np.arange(len(sensor_values)) / fs  # Time vector

      # Compute the spectrogram
      frequencies, times, spectrogram = signal.spectrogram(sensor_values, fs)

      # Compute the power spectral density
      frequencies, psd = signal.welch(sensor_values, fs=fs)

      # Calculate the PSD features
      alpha_power, beta_power, delta_power, theta_power, gamma_power = calculate_psd_features(normalized_sensor_values, fs)

      # Append the feature values to the lists
      alpha_powers.append(alpha_power)
      beta_powers.append(beta_power)
      alpha_beta_powers.append(alpha_power)
      alpha_beta_powers.append(beta_power)
      #delta_powers.append(delta_power)
      #theta_powers.append(theta_power)
      #gamma_powers.append(gamma_power)

  # print("Alpha PSD", alpha_powers)
  # print("Beta PSD", beta_powers)
  # print(ctr)
  # print("Alpha_Beta PSD", alpha_beta_powers)
  final_alpha_beta_p300.append(alpha_beta_powers)


  ctr+=1
print(final_alpha_beta_p300)
# Out:
# [[2.232927605658932, 3.9451445936649954, 2.496776884474632, 4.084575587981304, 2.3924717830123656, 3.5354594288478514, 2.3485610068129263, 3.7927251763207797, 1.5019153934023368, 2.79980362949123, 1.5823025729505065, 3.018916725141644, 1.1487190999137542, 2.1655577208940464, 2.354694635981416, 4.3097403167244455, 1.5401915008199403, 3.532632323621148, 2.9574806260935054, 5.106090797294496, 1.4257392522216414, 2.485961973707262, 2.3453017139032504, 3.7089142923383687, 2.560500180021605, 4.482317821724514, 1.4404502629282088, 2.8568336586737653, 2.5361857049712224, 4.492773612432868, 2.2637066319908814, 3.879200046801172, 2.108147783057601, 4.3971211681215], [1.327616056490127, 2.232259444520006, 1.8640037982595798, 3.0667632954036277, 2.219391594152854, 3.1515156602716465, 1.7902084605439217, 3.4500468977259704, 1.6135502017036538, 4.118205162698314, 1.687226643565158, 2.2838056213690163, 1.538884080269654, 3.4540677373182995, 2.1704784674229396, 4.134684425839339, 0.17000387937668343
# ...

# %%
import numpy as np

# Provided list
data_list = [[2.232927605658932, 3.9451445936649954, 2.496776884474632, 4.084575587981304, 2.3924717830123656, 3.5354594288478514, 2.3485610068129263, 3.7927251763207797, 1.5019153934023368, 2.79980362949123, 1.5823025729505065, 3.018916725141644, 1.1487190999137542, 2.1655577208940464, 2.354694635981416, 4.3097403167244455, 1.5401915008199403, 3.532632323621148, 2.9574806260935054, 5.106090797294496, 1.4257392522216414, 2.485961973707262, 2.3453017139032504, 3.7089142923383687, 2.560500180021605, 4.482317821724514, 1.4404502629282088, 2.8568336586737653, 2.5361857049712224, 4.492773612432868, 2.2637066319908814, 3.879200046801172, 2.108147783057601, 4.3971211681215], [1.327616056490127, 2.232259444520006, 1.8640037982595798, 3.0667632954036277, 2.219391594152854, 3.1515156602716465, 1.7902084605439217, 3.4500468977259704, 1.6135502017036538, 4.118205162698314, 1.687226643565158, 2.2838056213690163, 1.538884080269654, 3.4540677373182995, 2.1704784674229396, 4.134684425839339, 0.17000387937668343, 0.46977393505008974, 1.812464700994704, 3.142643416083712, 1.7806596747074281, 3.4445060321691088, 1.5840294422626962, 2.8682131066084944, 1.1686626190786749, 2.2734929001984643, 1.498991743035611, 3.436041125274004, 2.6174080840673906, 3.6092862361358984,
5.083117815217828, 2.5320879825839033, 3.474885270744891, 2.0560938556032022, 2.533451579716937, 2.685973353396454, 3.3049227159823555, 2.440648211305742, 4.083718849714582, 2.167845955408807, 2.962277820294665, 2.175285891532268, 2.834332644340767, 1.7475093803331028, 2.557517183095411], [7.218183233610949, 4.647203389856088, 6.883496798874425, 3.517530611845755, 8.701847801280337, 3.99839160502376, 6.803589021021183, 3.776624536016163, 6.171846256197522, 4.586124961759418, 5.290881001495041, 3.3569537462162446, 1.6617892924510318, 1.1616221247132519, 5.911426402679152, 4.664289766177598, 4.345215746395951, 2.8900622447796263, 15.360632862608433, 6.623720844883947, 2.884330218092044, 1.5183562691250374, 6.913058021865663, 3.562607715661663, 6.716828199190812, 2.8634786726716532, 3.611480818561303, 1.4438695499143666, 6.1434956559682075, 3.247671723853441, 6.111091146257129, 3.179767007846803, 2.8345894273258243, 2.064211991576586], [4.573935404401089, 2.258328165978659, 5.403048260136623, 2.56309526337926, 5.157886929972513, 2.3069410301501216, 5.529811132644714, 2.740503656671963, 4.702145197956739, 2.434724847537484, 6.684875399404689, 3.072633075599745, 7.194052421837888, 3.485369124256197, 8.007352311661904, 4.584603975189449, 4.008689735597072, 1.6575252624016907, 10.176592872239468, 5.002287445102431, 9.978169460963784, 3.9024414287781393, 8.671165920546143, 2.2837168014653106, 6.90993797152578, 2.4209837983127636, 8.694435957383739, 3.0806273536962947, 6.069746729172321, 2.2024352565968086, 5.134699721662617, 1.846360359323265, 5.634120796232839, 1.9904432269434045]]

# Split data into training and testing sets
X_train, X_test = train_test_split(data_array, test_size=0.2, random_state=42)

# Create and train the One-Class SVM model
clf = OneClassSVM(kernel='linear', gamma='scale', nu=0.01)  # You can adjust parameters as needed
clf.fit(X_train)

# Predict on the test set
predictions = clf.predict(X_test)

# Convert predictions to 0 (inlier) and -1 (outlier)
predictions[predictions == 1] = 0  # Inliers
predictions[predictions == -1] = 1  # Outliers

# Calculate accuracy
accuracy = accuracy_score(np.zeros(X_test.shape[0]), predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
 # Create a OneClassSVM instance
svm = OneClassSVM()

# Define the hyperparameters and their possible values for tuning
param_grid = {
    'nu': [0.01, 0.1, 0.2, 0.5],  # Anomaly proportion, adjust as needed
    'gamma': ['scale', 'auto', 0.1, 1.0, 10.0],  # Kernel coefficient, adjust as needed
}

# Create a GridSearchCV instance
grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)

# Fit the GridSearchCV on the data
grid_search.fit(data_array)

# Get the best hyperparameters
best_params = grid_search.best_params_

print("Best Hyperparameters:", best_params)

# Use the best model for predictions
best_model = grid_search.best_estimator_
predictions = best_model.predict(data_array)

print("Predictions:", predictions)

# %%
# Create a OneClassSVM instance
one_class_svm = OneClassSVM()

# Define the parameter grid for hyperparameter tuning
param_grid = {
    'nu': [0.01, 0.1, 0.2],  # Contamination level
    'kernel': ['linear', 'rbf'],  # Kernel type
    'gamma': ['scale', 'auto']  # Gamma parameter (for rbf kernel)
}

# Create GridSearchCV instance
grid_search = GridSearchCV(one_class_svm, param_grid, cv=3, scoring='accuracy')

# Fit the GridSearchCV to data
grid_search.fit(data_array)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
